# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanhVanLe0605/Data-Mining-For-Business-Analytics-In-Python/blob/main/Chapter_08_The_Naive_Bayes_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TABLE OF CONTENTS:
#
# * 8.1. [INTRODUCTION](https://colab.research.google.com/drive/1DVJucHgVuoXwnStP3Ohu4GpIX-JGmrlX#scrollTo=DnNDBrRu6jZ6&line=1&uniqifier=1)
# * 8.2. [APPLYING THE FULL (EXACT) BAYESIAN CLASSIFIER](https://colab.research.google.com/drive/1DVJucHgVuoXwnStP3Ohu4GpIX-JGmrlX#scrollTo=7tlbocSS69Jq&line=1&uniqifier=1)
# * 8.3. [ADVANTAGES AND SHORTCOMINGS OF THE NAIVE BAYES CLASSIFIER](https://colab.research.google.com/drive/1DVJucHgVuoXwnStP3Ohu4GpIX-JGmrlX#scrollTo=Q-cHb6_08va9&line=1&uniqifier=1)

# %% [markdown]
# # 8.1. INTRODUCTION

# %% [markdown]
# ## Cutoff Probability Method

# %% [markdown]
# ## Conditional Probability

# %% [markdown]
# **Example 1: Predicting Fraidilent Financial Reporting**

# %% [markdown]
# **TABLE 8.1. PIVOT TABLE FOR FINANCIAL REPORTING EXAMPLE**

# %% [markdown]
# # 8.2. APPLYING THE FULL (EXACT) BAYESIAN CLASSIFIER

# %% [markdown]
# ## Using the "Assign to the Most Probable Class" Method

# %% [markdown]
# ## Using the Cutoff Probability Method

# %% [markdown]
# ## Practical Difficulity with the Complete (Exact) Bayes Procedure

# %% [markdown]
# ## Solution: Naive Bayes

# %% [markdown]
# ## The Naive Bayes Assumption of Conditional Independence

# %% [markdown]
# ## Using the Cutoff Probability Method

# %% [markdown]
# **Example 2: Predicting Fraudulent Financial Reports, Two Predictors**

# %% [markdown]
# **TABLE 8.2. INFORMATION ON 10 COMPANIES**

# %% [markdown]
# **Complete (Exact) Bayes Calculations**

# %% [markdown]
# **Naive Bayes Calculations:**

# %% [markdown]
# **Example 3: Predicting Delayed Flights**

# %% [markdown]
# **Table 8.3. DESCRIPTION OF VARIABLES FOR FLIGHT DELAYS EXAMPLE**

# %% [markdown]
# **TABLE 8.4. NAIVE BAYES CLASSIFIER APPLIED TO FLIGHT DELAYS (TRAINING) DATA**

# %% [markdown]
# **TABLE 8.5. PIVOT TABLE OF FLIGHT STATUS BY DESTINATION AIRPORT (TRAINING DATA)**

# %% [markdown]
# **TABLE 8.6. SCORING THE EXAMPLE FLIGHT (PROBABILITY AND CLASS)**

# %% [markdown]
# **TABLE 8.7. CONFUSION MATRICES FOR FLIGHT DELAY USING THE NAIVE BAYES CLASSIFIER**

# %% [markdown]
# # 8.3. ADVANTAGES AND SHORTCOMINGS OF THE NAIVE BAYES CLASSIFIER

# %% [markdown]
# **FIGURE 8.1. CUMULATIVE GAINS CHART OF NAIVE BAYES CLASSIFIER APPLIED TO FLIGHT DELAYS DATA**

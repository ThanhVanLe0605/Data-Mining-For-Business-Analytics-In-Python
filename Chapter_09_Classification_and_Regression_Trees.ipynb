# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanhVanLe0605/Data-Mining-For-Business-Analytics-In-Python/blob/main/Chapter_09_Classification_and_Regression_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TABLE OF CONTENT
#
# * 9.1. [INTRODUCTION](https://colab.research.google.com/drive/1BhFs2KGYybK6__oHMrnUPPofulAIWBuv#scrollTo=N9vmOV7cpM1j&line=1&uniqifier=1)
# * 9.2. [Classfication Trees](https://colab.research.google.com/drive/1BhFs2KGYybK6__oHMrnUPPofulAIWBuv#scrollTo=NWupqY8ny4Iv&line=1&uniqifier=1)
# * 9.3. [EVALUATING THE PERFORMANCE OF A CLASSIFICATION TREE](https://colab.research.google.com/drive/1BhFs2KGYybK6__oHMrnUPPofulAIWBuv#scrollTo=ePgHwgj703jM&line=1&uniqifier=1)
# * 9.4. [AVOIDING OVERFITTING](https://colab.research.google.com/drive/1BhFs2KGYybK6__oHMrnUPPofulAIWBuv#scrollTo=Ld-rvW-u192j&line=1&uniqifier=1)
# * 9.5. [CLASSIFICATION RULES FROM TREES](https://colab.research.google.com/drive/1BhFs2KGYybK6__oHMrnUPPofulAIWBuv#scrollTo=Dp-FDJbO3Zg-&line=1&uniqifier=1)
# * 9.6. [CLASSIFICATION TREES FOR MORE THAN TWO CLASSES](https://colab.research.google.com/drive/1BhFs2KGYybK6__oHMrnUPPofulAIWBuv#scrollTo=h6bIrX0C3d14&line=1&uniqifier=1)
# * 9.7. [REGRESSION TREES](https://colab.research.google.com/drive/1BhFs2KGYybK6__oHMrnUPPofulAIWBuv#scrollTo=wD_1I1MX3jq7&line=1&uniqifier=1)
# * 9.8. [IMPROVING PREDICTION: RANDOM FORESTS AND BOOSTED TREES](https://colab.research.google.com/drive/1BhFs2KGYybK6__oHMrnUPPofulAIWBuv#scrollTo=cg0TEo2S3_iB&line=1&uniqifier=1)
# * 9.9. [ADVANTAGES AND WEAKNESSES OF A TREE](https://colab.research.google.com/drive/1BhFs2KGYybK6__oHMrnUPPofulAIWBuv#scrollTo=MVLOpPga4mN8&line=1&uniqifier=1)

# %% [markdown]
# # 9.1. INTRODUCTION

# %% [markdown]
# **Figure 9.1. Example of a tree for classifying bank customers as loan acceptors or nonacceptors**

# %% [markdown]
# ## Tree Structure

# %% [markdown]
# ## Decision Rules

# %% [markdown]
# ## Classifying a New Record

# %% [markdown]
# # 9.2. Classfication Trees

# %% [markdown]
# ## Recursive Partitioning

# %% [markdown]
# **Example 1: Riding Mowers**

# %% [markdown]
# **Table 9.1. LOT SIZE, INCOME, AND OWNERSHIP OF A RIDING MOWER FOR 24 HOUSEHOLDS**

# %% [markdown]
# **FIGURE 9.2. SCATTER PLOT OF LOT SIZE VS.INCOME FOR 24 OWNERS AND NONOWNERS OF RIDING MOWERS**

# %% [markdown]
# **FIGURE 9.3. SPLITTING THE 24 RECORDS BY INCOME VALUE OF 59.7**

# %% [markdown]
# ## MEASURES OF IMPOURITY

# %% [markdown]
# **FIGURE 9.4. VALUES OF THE GINI INDEX FOR A TWO-CLASS CASE AS A FUNCTION OF THE PROPORTION OF RECORDS IN CLASS 1 (p1)**

# %% [markdown]
# **FIGURE 9.5. SPLITTING THE 24 HOURS FIRST BY INCOME VALUE OF 59.7 AND THEN LOT SIZE VALUE OF 21.4**

# %% [markdown]
# **FIGURE 9.6. FINAL STAGE OF RECURSIVE PARTITIONING; EACH RECTANGLE CONSISTING OF A SINGLE CLASS (OWNERS OR NONOWNERS)**

# %% [markdown]
# **FIGURE 9.7. THE REPRESENTATION OF FIRST SPLIT (CORRESPONDS TO FIGURE 9.3)**

# %% [markdown]
# **FIGURE 9.8 TREE REPRESENTATION OF FIRST THREE SPLITS**

# %% [markdown]
# **FIGURE 9.9. TREE REPRESENTATION AFTER ALL SPLITS (CORRESPONDS TO FIGURE 9.6). THIS IS THE FULL GROWN TREE**

# %% [markdown]
# # 9.3. EVALUATING THE PERFORMANCE OF A CLASSIFICATION TREE

# %% [markdown]
# **Example 2: Acceptance of Personal Loan**

# %% [markdown]
# **TABLE 9.2. SAMPLE OF DATA FOR 20 CUSTOMERS OF UNIVERSAL BANK**

# %% [markdown]
# ## Sensitivity Analysis Using Cross Validation

# %% [markdown]
# **FIGURE 9.10. A FULL TREE FOR THE LOAD ACCEPTANCE DATA USING THE TRAINING SET (3000 RECORDS)**

# %% [markdown]
# **TABLE 9.3. CONFUSION MATRICES AND ACCURACY FOR THE DEFAULT (FULL) CLASSIFICATION TREE, ON THE TRAINING AND VALIDATION SETS OF THE PERSONAL LOAN DATA**

# %% [markdown]
# **TABLE 9.4. ACCURACY OF THE DEFAULT (FULL) CLASSIFICATION TREE, ON FIVE VALIDATION FOLDS USING 5-FOLD CROSS-VALIDATION**

# %% [markdown]
# # 9.4. AVOIDING OVERFITTING

# %% [markdown]
# **FIGURE 9.11. ERROR RATE AS A FUNCTION OF THE NUMBER OF SPLITS FOR TRAINING VS. VALIDATION DATA: OVERFITTING**

# %% [markdown]
# ## STOPPING TREE GROWTH

# %% [markdown]
# **FIGURE 9.12. SMALLER CLASSIFICATION TREE FOR THE LOAN ACCEPTANCE DATA  USING THE TRAINING SET (3000 RECORDS)**

# %% [markdown]
# ## FINE-TUNING TREE PARAMETERS

# %% [markdown]
# **TABLE 9.5. CONFUSION MATRICES AND ACCURACY FOR THE SMALL CLASSIFICATION TREE, ON THE TRAINING AND VALIDATION SETS OF THE PERSONAL LOAN DATA**

# %% [markdown]
# **TABLE 9.6. EXHAUSTIVE GRID SEARCH TO FINE TUNE METHOD PARAMETERS**

# %% [markdown]
# ## OTHER METHODS FOR LIMITING TREE SIZE

# %% [markdown]
# **FIGURE 9.13. FINE-TUNED CLASSIFICATION TREE FOR THE LOAN ACCEPTANCE DATA USING THE TRAINING SET (3000 RECORDS)**

# %% [markdown]
# # 9.5 CLASSIFICATION RULES FROM TREES

# %% [markdown]
# # 9.6. CLASSIFICATION TREES FOR MORE THAN TWO CLASSES

# %% [markdown]
# # 9.7. REGRESSION TREES

# %% [markdown]
# ## PREDICTION

# %% [markdown]
# ## MEASURING IMPURITY

# %% [markdown]
# **FIGURE 9.14. FINE-TUNED REGRESSION TREE FOR TOYATA COROLLA PRICES**

# %% [markdown]
# ## EVALUATING PERFORMANCE

# %% [markdown]
# **TABLE 9.7. TRAIN AND EVALUATE A FINE-TUNED REGRESSION TREE**

# %% [markdown]
# # 9.8 IMPROVING PREDICTION: RANDOM FORESTS AND BOOSTED TREES

# %% [markdown]
# ## RANDOM FORESTS

# %% [markdown]
# **TABLE 9.8. RANDOM FOREST (PERSONAL LOAN EXAMPLE)**

# %% [markdown]
# ## BOOSTED TREES

# %% [markdown]
# **FIGURE 9.15. VARIABLE IMPORTANCE PLOT FROM RANDOM FOREST (PERSONAL LOAN EXAMPLE, FOR CODE SEE TABLE 9.8)**

# %% [markdown]
# **TABLE 9.9. BOOSTED TREE: CONFUSION MATRIX FOR THE VALIDATION SET (LOAN DATA)**

# %% [markdown]
# # 9.9. ADVANTAGES AND WEAKNESSES OF A TREE

# %% [markdown]
# **FIGURE 9.16. A TWO-PREDICTOR CASE WITH 2 CLASSES. THE BEST SEPARATION IS ACHIEVED WITH A DIAGONAL LINE, WHICH CLASSIFICATION TREES CANNOT DO**

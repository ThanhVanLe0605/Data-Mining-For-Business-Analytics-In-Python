# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanhVanLe0605/Data-Mining-For-Business-Analytics-In-Python/blob/main/Chapter_07_k_Nearest_Neighbors(k_NN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TABLE OF CONTENTS:
# * 7.1. [THE K-NN CLASSIFIER (CATEGORICAL OUTCOME)](https://colab.research.google.com/drive/1fKGq1PWuGCy2D9Ob5FR0x5gtd8I9Mb7R#scrollTo=eA0AGGvY9y0-&line=1&uniqifier=1)
# * 7.2. [k-NN FOR A NUMERICAL OUTCOME](https://colab.research.google.com/drive/1fKGq1PWuGCy2D9Ob5FR0x5gtd8I9Mb7R#scrollTo=9PyVLX49_1vK&line=1&uniqifier=1)
# * 7.3. [ADVANTAGES AND SHORTCOMINGS OF k-NN ALGORITHMS](https://colab.research.google.com/drive/1fKGq1PWuGCy2D9Ob5FR0x5gtd8I9Mb7R#scrollTo=za0eninX_57O&line=1&uniqifier=1)

# %% [markdown]
# # 7.1. THE K-NN CLASSIFIER (CATEGORICAL OUTCOME)

# %% [markdown]
# ## Determining Neighbors

# %% [markdown]
# ## Classification Rule

# %% [markdown]
# **Example: Riding Mowers**

# %% [markdown]
# **TABLE 7.1. LOT SIZE, INCOME AND OWNERSHIP OF A RIDING MOWER FOR 24 HOUSEHOLDS**

# %% [markdown]
# ## Choosing k

# %% [markdown]
# **FIGURE 7.1. SCATTER PLOT OF LOT SIZE VS.INCOME FOR THE 14 TRAINING SET HOUSEHOLDS (SOLID MARKERS). 10 VALIDATION SET HOUSEHOLDS (HOLLOW MARKERS) AND THE NEW HOUSEHOLD TO BE CLASSIFIED**

# %% [markdown]
# **TABLE 7.2. RUNNING k-NN**

# %% [markdown]
# **TABLE 7.3. ACCURACY (OR CORRECT RATE) OF k-NN PREDICTIONS IN VALIDATION SET FOR VARIOUS CHOICES OF k**

# %% [markdown]
# ## Setting the Cutoff Value

# %% [markdown]
# **TABLE 7.4. CLASSIFYING A NEW HOUSEHOLD USING THE "BEST K" = 4**

# %% [markdown]
# ## k-NN WITH MORE THAN TWO CLASSES

# %% [markdown]
# ## CONVERTING CATEGORICAL VARIABLES TO BINARY DUMMIES

# %% [markdown]
# # 7.2. k-NN FOR A NUMERICAL OUTCOME

# %% [markdown]
# # 7.3. ADVANTAGES AND SHORTCOMINGS OF k-NN ALGORITHMS
